# %%
import math
print("square root f 16:",math.sqrt(16))
print("2 raised to power 6:",math.pow(2,6))
print("the value of pi:",math.pi)
print("the value of Euler's number:",math.e)

print("sin (90):",math.sin(math.radians(90)))
print("cos (90):",math.cos(math.radians(90)))
print("tan(45):",math.tan(math.radians(45)))


print("natyral log e:",math.log(math.e))
# Out:
# square root f 16: 4.0
# 2 raised to power 6: 64.0
# the value of pi: 3.141592653589793
# the value of Euler's number: 2.718281828459045
# sin (90): 1.0
# cos (90): 6.123233995736766e-17
# tan(45): 0.9999999999999999
# natyral log e: 1.0

# %%
import time
print(time.time())
print(time.localtime(time.time()))
print(time.asctime(time.localtime(time.time())))
# Out:
# 1758775382.7086108
# time.struct_time(tm_year=2025, tm_mon=9, tm_mday=25, tm_hour=4, tm_min=43, tm_sec=2, tm_wday=3, tm_yday=268, tm_isdst=0)
# Thu Sep 25 04:43:02 2025

# %%
import random
print("Random float value  between 0 and 1:",random.random())
# Out:
# Random float value  between 0 and 1: 0.3131569932275453

# %%
import math
import random
import datetime
# List of questions (using math functions)
questions = [
("What is the square root of 81?", math.sqrt(81)),
("What is 2 raised to power 6?", math.pow(2, 6)),
("What is factorial of 5?", math.factorial(5)),
("What is sin(90°)?", round(math.sin(math.radians(90)), 2)),
("What is log base 10 of 1000?", math.log10(1000))
]
# Shuffle questions randomly
random.shuffle(questions)
print("🎯 Welcome to the Math Quiz Game!")
print("You have 5 questions. Let's begin...\n")
score = 0
start_time = datetime.datetime.now() # Start timer
for i, (q, ans) in enumerate(questions, 1):
  print(f"Q{i}: {q}")
  user_answer = input("Your answer: ")
  try:

     if abs(float(user_answer) - float(ans)) < 0.01: # Tolerance for float comparison
         print("✅ Correct!\n")
         score += 1
     else:
         print(f"❌ Wrong! Correct Answer = {ans}\n")
  except:
        print(f"⚠ Invalid input! Correct Answer = {ans}\n")
end_time = datetime.datetime.now() # End timer
time_taken = end_time - start_time
print("🎉 Quiz Over!")
print(f"Your Score: {score} / {len(questions)}")
print(f"Time Taken: {time_taken.seconds} seconds")
# Out:
# 🎯 Welcome to the Math Quiz Game!
# You have 5 questions. Let's begin...
#
# Q1: What is log base 10 of 1000?
# Your answer: 3
# ✅ Correct!
#
# Q2: What is the square root of 81?
# Your answer: 9
# ✅ Correct!
#
# Q3: What is 2 raised to power 6?
# Your answer: 64
# ✅ Correct!
#
# Q4: What is sin(90°)?
# Your answer: 0.893996664
# ❌ Wrong! Correct Answer = 1.0
#
# Q5: What is factorial of 5?
# Your answer: 120
# ✅ Correct!
#
# 🎉 Quiz Over!
# Your Score: 4 / 5
# Time Taken: 102 seconds
