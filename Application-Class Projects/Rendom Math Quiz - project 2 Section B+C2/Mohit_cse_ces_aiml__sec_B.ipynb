# %%
import math
print("Square root of 16:",math.sqrt(16))
print("Pi:",math.pi)
print("Euler:",math.e)
# Out:
# Square root of 16: 4.0
# Pi: 3.141592653589793
# Euler: 2.718281828459045

# %%
print(math.sin(math.radians(90)))
print(math.tan(math.radians(45)))
# Out:
# 1.0
# 0.9999999999999999

# %%
print(math.log(math.e))
print(math.ceil(4.3))
print(math.floor(4.8))
print(math.factorial(5))
# Out:
# 1.0
# 5
# 4
# 120

# %%
import datetime
now=datetime.datetime.now()
print(now)
print(now.date)
print(now.time())
# Out:
# 2025-09-25 04:40:07.442302
# <built-in method date of datetime.datetime object at 0x7992a9ea7450>
# 04:40:07.442302

# %%
d= datetime.date(2025,9,24)
print(d)
print(now.strftime("%d"))
from datetime import timedelta
# Out:
# 2025-09-24
# 25

# %%
import random
print(random.random())
print(random.randint(1,10))
colors=["Red","Yellow","Blue"]
print(random.choice(colors))
# Out:
# 0.44318911318444765
# 7
# Yellow

# %%
import math
import datetime
import random
questions=[
    ("What is the square root of 100?",math.sqrt(100)),
    ("What is 2 raised to power 5?",math.pow(2,5)),
    ("What is factorial of 8?",math.factorial(8)),
    ("What is Sin(90)",round(math.sin(math.radians(90)),2)),
    ("What is log base 10 of 1000?",math.log(1000))
]

print("Welcome to the Quiz Game!")
print("You have 5 questions. Let's begin..\n")

score=0
start_time=datetime.datetime.now()
for i,(q,ans) in enumerate(questions,1):
  print(f"Q{i}:{q}")
  user_answer=input("your answer: ")
  try:
    if abs(float(user_answer) -float(ans)) <0.01:
      print("Correct\n")
      score+=1
    else:
      print(f"Wrong! Correct Answer={ans}\n")
  except:
    print(f"Invalid input! Correct Answer={ans}\n")
end_time=datetime.datetime.now()
time_taken=end_time-start_time

print("Quiz Over!")
print(f"Your Score:{score}/{len(questions)}")
print(f"Time Taken:{time_taken.seconds}seconds")
# Out:
# Welcome to the Quiz Game!
# You have 5 questions. Let's begin..
#
# Q1:What is the square root of 100?
# your answer: 10
# Correct
#
# Q2:What is 2 raised to power 5?
# your answer: 32
# Correct
#
# Q3:What is factorial of 8?
# your answer: 40320
# Correct
#
# Q4:What is Sin(90)
# your answer: 1
# Correct
#
# Q5:What is log base 10 of 1000?
# your answer: 3
# Wrong! Correct Answer=6.907755278982137
#
# Quiz Over!
# Your Score:4/5
# Time Taken:24seconds
