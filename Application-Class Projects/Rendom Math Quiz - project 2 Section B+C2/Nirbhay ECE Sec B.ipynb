# %%
import math
print("Pi:",math.pi)
print("Euler's Number: ",math.e)
# Out:
# Pi: 3.141592653589793
# Euler's Number:  2.718281828459045

# %%
print("sin(90): ", math.sin(math.radians(90)))
print("cos(0): ", math.cos(math.radians(0)))
print("tan(45): ", math.tan(math.radians(45)))
# Out:
# sin(90):  1.0
# cos(0):  1.0
# tan(45):  0.9999999999999999

# %%
print("Natural log of e: ", math.log(math.e))
print("Log base 10 of 100: ", math.log(100, 10))
# Out:
# Natural log of e:  1.0
# Log base 10 of 100:  2.0

# %%
print("Ceil of 4.2: ", math.ceil(4.2))
print("Floor of 4.2: ", math.floor(4.2))
print("Factorial of 5: ", math.factorial(5))
# Out:
# Ceil of 4.2:  5
# Floor of 4.2:  4
# Factorial of 5:  120

# %%
import datetime
now = datetime.datetime.now()
print("date and time", now)
print("date", now.date)
print("time", now.time())
# Out:
# date and time 2025-09-25 04:45:12.158208
# date <built-in method date of datetime.datetime object at 0x7b48297dd770>
# time 04:45:12.158208

# %%
import math
import random
import datetime

#list of question
questions= [
    ("What is the square root of 81?", math.sqrt(81)),
     ("what is 2 raised to power 6?", math.pow(2,6)),
     ("what is factorial of 5?", math.factorial(5)),
     ("what is sin(90)?", round(math.sin(math.radians(90)),2)),
    ("what is log base 10 of 1000?", math.log10(1000))
]



#shuffle questions randomly
random.shuffle(questions)

print("Welcome to the math quiz game!")
print("You have 5 questions to answer.")

score = 0
start_time = datetime.datetime.now()

for i,(q,ans) in enumerate(questions,1):
    print(f"Question {i}: {q}")
    user_answer = input("Your answer: ")



    try:
          if abs(float(user_answer) - float(ans)) < 0.01:
            print("Correct!\n")
            score +=1
          else:
            print(f"Wrong! Correct answer = {ans}\n")
    except:
      print(f"Invalid input! Correct answer = {ans}\n")



end_time = datetime.datetime.now()
time_taken = end_time - start_time


print("Quiz Over!")
print(f"Your Score: {score} / {lenm(questions)}")
print(f"Time taken: {time_taken.seconds} seconds")
# Out:
# Welcome to the math quiz game!
# You have 5 questions to answer.
# Question 1: what is log base 10 of 1000?
