# %%
import math
import random
import datetime

question = [
    (" what is the square root of 81 ?" , math . sqrt(81)),
    (" what is 2 raised to the power 6?", math.pow(2,6)),
    (" what is factorial of 5?", math . factorial(5)),
    ("what i sin (90*)? " , round ( math . sin ( math . radians (90)), 2)),
    (" what is log base 10 of 1000?" , math . log10 (1000))
]
random .shuffle(question)
print( " welcome to the math quiz game !")
print ( " you have 5 question . let's begin ...\n")

score = 0
start_time = datetime.datetime.now()

for i , ( q , ans ) in enumerate( question, 1):
    print(F" q {i}: { q}")
    user_answer = input (" your answer: ")

    try:
        if abs ( float ( user_answer) - float(ans)) < 0.01:
            print("correct!\n")
            score += 1
        else:
            print( f" wrong! correct answer = { ans } \n")
    except ValueError:
        print(f" Invalid input ! correct answer = { ans}\n")

end_time = datetime.datetime.now()
time_taken = end_time - start_time

print(" quiz Over!")
print(f"Your score: { score}/ { len(question)}")
print(f"Time taken : { time_taken.seconds} seconds")
# Out:
#  welcome to the math quiz game !
#  you have 5 question . let's begin ...
#
#  q 1:  what is log base 10 of 1000?
#  your answer: 3
# correct!
#
#  q 2:  what is factorial of 5?
#  your answer: 120
# correct!
#
#  q 3:  what is 2 raised to the power 6?
#  your answer: 64
# correct!
#
#  q 4: what i sin (90*)?
#  your answer: 1
# correct!
#
#  q 5:  what is the square root of 81 ?
#  your answer: 9
# correct!
#
#  quiz Over!
# Your score: 5/ 5
# Time taken : 22 seconds
