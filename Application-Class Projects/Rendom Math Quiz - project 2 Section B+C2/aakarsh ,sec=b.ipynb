# %%
import math

# %%
print("square root of 16:" , math.sqrt(16))
print("2 raised to power 5:", math.pow(2,5))
# Out:
# square root of 16: 4.0
# 2 raised to power 5: 32.0

# %%
import math
import random
import datetime

questions = [
    ("what is the square root of 169?", math.sqrt(81)),
    ("what is 2 raised to power 6?", math.pow(2,8)),
    ("what is factorial of 6?", math.factorial(6)),
    ("what is sin(90)?", round(math.sin(math.radians(90)), 2)),
    ("what is the log base 10 of 100000?", math.log10(100000))
]

random.shuffle(questions)

print("welcome to the math quiz game!")
print("you have 5 questions. let's begin...\n")

score = 0
start_time = datetime.datetime.now()

for i, (q, ans) in enumerate( questions, 1):
    print(f"Q{i}: {q}")
    user_answer = input("your answer: ")

    try:
        if abs(float(user_answer) - float(ans)) < 0.01:
            print("correct!\n")
            score+= 1
        else:
            print(f" wrong! correct answer = {ans}\n")
    except:
        print(f"invalid input! correct answer = {ans}\n")

end_time = datetime.datetime.now()
time_taken = end_time - start_time

print("quiz over!")
print(f"your score: {score}/ {len(questions)}")
print(f"time taken: {time_taken.seconds} seconds")
# Out:
# welcome to the math quiz game!
# you have 5 questions. let's begin...
#
# Q1: what is 2 raised to power 6?
# your answer: 64
#  wrong! correct answer = 256.0
#
# Q2: what is sin(90)?
# your answer: 1
# correct!
#
# Q3: what is the log base 10 of 100000?
# your answer: 5
# correct!
#
# Q4: what is the square root of 169?
# your answer: 13
#  wrong! correct answer = 9.0
#
# Q5: what is factorial of 6?
# your answer: 120
#  wrong! correct answer = 720
#
# quiz over!
# your score: 2/ 5
# time taken: 99 seconds
