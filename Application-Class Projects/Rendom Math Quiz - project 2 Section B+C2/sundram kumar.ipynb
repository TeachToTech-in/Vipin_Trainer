# %%
import math
print("Square root of 16:", math.squr(16))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2668261678.py in <cell line: 0>()
#       1 import math
# ----> 2 print("Square root of 16:", math.squr(16))
#
# AttributeError: module 'math' has no attribute 'squr'

# %%
import math
print("Pi:", math.pi)
print("Euler's number:", math.e)
# Out:
# Pi: 3.141592653589793
# Euler's number: 2.718281828459045

# %%
print("Natural log of e:", math.log(math.e))
print("Log base 10 of 100:", math.log10(100))
# Out:
# Natural log of e: 1.0
# Log base 10 of 100: 2.0

# %%
import datetime
now = datetime.datetime.now()
print("Current Date& Time:",now)
print("Only Date:", now.date)
print("Only Time:", now.time())
# Out:
# Current Date& Time: 2025-09-25 04:44:16.919349
# Only Date: <built-in method date of datetime.datetime object at 0x7ee3d48ef780>
# Only Time: 04:44:16.919349

# %%
date1 = datetime.date(2025,9,25)
date2 = datetime.date(2008,1,4)
diff = date2 - date1
print("Date Difference:", diff.days)
# Out:
# Date Difference: -6474

# %%
import math
import random
import datetime
questions = [
    ("What is the squre root of 81?", math.squrt(81)),
    ("What is 2 raised to power 6?", math.pow(2, 6)),
    ("What is factorial of 5?", math.factorial(5)),
    ("What is sin(90)?", round(math.sin(math.radians(90)), 2)),
    ("What is log base 10 of 1000?", math.log10(1000))
]
random.shuffle(questions)

print("Welcom to the Math Quiz Game!")
print("You have 5 question. Let's begin...\n")
score = 0
start_time = datetime.datetime.now()
for i, (q, ans) in enumerate(questions,1):
  print(f"Q{i}: {q}")
  user_answer = input("Your answer:")
  try:
       if abs(float(user_answer) - float(ans)) < 0.01:
        print("Corret!\n")
        score +=1
       else:
         print(f"Wrong! Correct Answe == {ans}\n")
  except:
           print(f"Invalid input! Coorect Answer = {ans}\n"):
  end_time = datetime.datetime.now()
  time_taken = end_time - start_time
  print("Quiz Over!")
  print(f"Your Score: {score} / {len(questions)}")
  print(f"Time Taken: {time_taken.seconds} seconds")
