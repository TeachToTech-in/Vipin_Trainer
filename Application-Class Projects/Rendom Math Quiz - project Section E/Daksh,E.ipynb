# %%
import math
import random
import datetime

questions = [
    ("What is the square root of                                                                                                                                                                                                                                                                                                                                                                               )
]

# %%
import math
import random
import datetime

questions = [
    ("what is the square root of 144?", math.sqrt(144)),
    ("what is 5 raised to power 4?", math.pow(5, 4)),
    ("what is the factorial of 6?", math.factorial(6)),
    ("what s sin(90)?", round(math.sin(math.radians(90)), 2)),
    ("what is log base of 1000?", math.log10(1000))
]

random.shuffle(questions)

print("welcome to the math quiz game!")
print("you have 5 questions. let's begin...\n")

score = 0
start_time = datetime.datetime.now()

for i, (q, ans) in enumerate(questions, 1):
  print(f"q{i}: {q}")
  user_answer = input("your answer: ")

  try:
      if abs(float(user_answer) - float(ans)) < 0.01:
          print("correction!\n")
          score += 1
      else:
          print(f"wrong! correct answer = {ans}\n")
  except:
      print(f"invalid input! correct answer = {ans}\n")

end_time = datetime.datetime.now()
time_taken = end_time - start_time

print("quiz over!")
print(f"your score: {score} / {len(questions)}")
print(f"time taken: {time_taken.seconds} seconds")
# Out:
# welcome to the math quiz game!
# you have 5 questions. let's begin...
#
# q1: what is the factorial of 6?
# your answer: 720
# correction!
#
# q2: what is log base of 1000?
# your answer: 100
# wrong! correct answer = 3.0
#
# q3: what s sin(90)?
# your answer: 1
# correction!
#
# q4: what is the square root of 144?
# your answer: 12
# correction!
#
# q5: what is 5 raised to power 4?
# your answer: 625
# correction!
#
# quiz over!
# your score: 4 / 5
# time taken: 26 seconds
