# %%
import os

# %%
with open("sample.txt", "w") as f:
    f.write("hello OS Module!")
print("Before rename:", os.listdir())

os.rename("sample.txt", "rename.txt")
print("After rename:", os.listdir())

os.remove("rename.txt")
print("After remove:", os.listdir())
# Out:
# Before rename: ['.config', 'sample.txt', 'sample_data']
# After rename: ['.config', 'rename.txt', 'sample_data']
# After remove: ['.config', 'sample_data']

# %%
print("OS Name:", os.name)
print("PATH variable:", os.environ.get("PATH"))
print("Process ID:", os.getpid())
print("CPU Count:", os.cpu_count())
# Out:
# OS Name: posix
# PATH variable: /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# Process ID: 319
# CPU Count: 2

# %%
file_path = "demo.txt"

with open(file_path,"w")as f:
    f.write("Testing os.path")

print("Join path :",os.path.join("/content",(file_path)))
print("Exists:", os.path.exists(file_path))
print("Is File :", os.path.isfile(file_path))
print("Absolute path:", os.path.abspath(file_path))
print("Base Name:", os.path.basename("/content/demo.txt"))
print("Dir Name:", os.path.dirname("/content/demo.txt"))
# Out:
# Join path : /content/demo.txt
# Exists: True
# Is File : True
# Absolute path: /content/demo.txt
# Base Name: demo.txt
# Dir Name: /content

# %%
import sys

print("python Version:", sys.version)
print("python Version Info:", sys.version_info)
# Out:
# python Version: 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# python Version Info: sys.version_info(major=3, minor=12, micro=11, releaselevel='final', serial=0)

# %%
print("System Path Direc")
